# %%
def memo(m,d):
    if m in d:
        return d[m]
    else:
        d[m] = memo(m-1,d)+memo(m-2,d)
        return d[m]
d = {0:1,1:1}

# %%
print(memo(5,d))
# Out:
# 8

# %% [markdown]
# # FIRST PYTHON PROGRAMMING LECTURE

# %%
print("Hello World")
print(100)
print(3.14)
# Out:
# Hello World
# 100
# 3.14

# %%
city = "Mumbai"
state = "Maharashtra"
country = "India"
print(f"City {city} SWtate {state} Country {country}")
# Out:
# City Mumbai SWtate Maharashtra Country India

# %%
length = int(input("Enter length"))
width = int(input("Enter width"))
UNIT = "cm"
print(f'Area = {length*width} {UNIT}\N{SUPERSCRIPT TWO}')
# Out:
# Area = 1452 cm²

# %%
f = float(input())
i = int(f)
print(type(f))
print(type(i))
# Out:
# <class 'float'>
# <class 'int'>

# %% [markdown]
# # OPERATORS IN PYTHON

# %%
a,b = map(int,input("ENTER TWO INTEGERS SEPARATED BY A SPACWE").split())
print(a+b , a*b , a/b , a-b)
# Out:
# 3 2 0.5 -1

# %%
a = int(input("Enter a integer"))
if a%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
a,b = map(int,input("ENTER TWO INTEGERS SEPARATED BY A SPACWE").split())
if a>b:
    print(a,"is greater")
else:
    print(b,"is greater")
# Out:
# 13 is greater
